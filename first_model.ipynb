# %%
print "om namo narayana"
# Out:
# om namo narayana

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from time import sleep
from mpl_toolkits import mplot3d
from numpy.linalg import inv
from mpl_toolkits.mplot3d import Axes3D

# %%
a = np.array([1,2,3,4,5])
b = np.array([10,9,8,7,6])
c = b - a
print(c)
# Out:
# [9 7 5 3 1]

# %%
c**2
# Out:
# array([81, 49, 25,  9,  1])

# %%
def seq(X, Y, batch_size):
    print sum(np.array(X) - np.array(Y))
    #return float(sum((np.array(X) - np.array(Y))**2) )/float(2 * batch_size)

# %%
inv([[1,2], [2,1]])
# Out:
# array([[-0.33333333,  0.66666667],
#        [ 0.66666667, -0.33333333]])

# %%
df = pd.read_csv(r'D:\spider\machine_learning\testset.csv')

# %%
df.head()
# Out:
#      datetime_utc  _conds   _dewptm   _fog   _hail   _heatindexm   _hum  \
# 0  19961101-11:00   Smoke       9.0      0       0           NaN   27.0
# 1  19961101-12:00   Smoke      10.0      0       0           NaN   32.0
# 2  19961101-13:00   Smoke      11.0      0       0           NaN   44.0
# 3  19961101-14:00   Smoke      10.0      0       0           NaN   41.0
# 4  19961101-16:00   Smoke      11.0      0       0           NaN   47.0
#
#     _precipm   _pressurem   _rain   _snow   _tempm   _thunder   _tornado  \
# 0        NaN       1010.0       0       0     30.0          0          0
# 1        NaN      -9999.0       0       0     28.0          0          0
# 2        NaN      -9999.0       0       0     24.0          0          0
# 3        NaN       1010.0       0       0     24.0          0          0
# 4        NaN       1011.0       0       0     23.0          0          0
#
#     _vism   _wdird  _wdire   _wgustm   _windchillm   _wspdm
# ...

# %%
data = df.iloc[0:(df.shape[0])/2, :]#for selecting the rows and columns
test_data = df.iloc[df.shape[0]/2:, :]

# %%
print(df.shape)
print(test_data.shape)
print(data.shape)
# Out:
# (100990, 20)
# (50495, 20)
# (50495, 20)

# %%
booleans_rain = []
for i in data[data.columns[9]]:
    booleans_rain.append(i != 0)
data_rain = (data[booleans_rain])
#print data_rain[' _rain']

# %%
booleans_rain_fog = []
for i in data_rain[data_rain.columns[3]]:
    booleans_rain_fog.append(i != 0)
print(data_rain[booleans_rain_fog])
# Out:
# Empty DataFrame
# Columns: [datetime_utc,  _conds,  _dewptm,  _fog,  _hail,  _heatindexm,  _hum,  _precipm,  _pressurem,  _rain,  _snow,  _tempm,  _thunder,  _tornado,  _vism,  _wdird,  _wdire,  _wgustm,  _windchillm,  _wspdm]
# Index: []

# %%
data_rain.columns
tmp = []
tmp.append(data)
#print (tmp[0])

# %%
data_time = []
for j in range (10):
    booleans_time = []
    for i in data[data.columns[0]]:
        booleans_time.append("0"+str(j)+":00" in i)
    data_time.append(data[booleans_time])
for j in range (10, 24):
    booleans_time = []
    for i in data[data.columns[0]]:
        booleans_time.append(str(j)+":00" in i)
    data_time.append(data[booleans_time])

# %%
#print (data_time[4]['datetime_utc'])

# %%
data.columns
# Out:
# Index([u'datetime_utc', u' _conds', u' _dewptm', u' _fog', u' _hail',
#        u' _heatindexm', u' _hum', u' _precipm', u' _pressurem', u' _rain',
#        u' _snow', u' _tempm', u' _thunder', u' _tornado', u' _vism',
#        u' _wdird', u' _wdire', u' _wgustm', u' _windchillm', u' _wspdm'],
#       dtype='object')

# %%
data_time[0].shape
# Out:
# (476, 20)

# %%
X = data_time[1]['datetime_utc'].tolist()
Y = data_time[1][' _dewptm'].tolist()

# %%
plt.plot(X[:100], Y[:100])

# %%
#data_time

# %%
data_rain
# Out:
#          datetime_utc                        _conds   _dewptm   _fog   _hail  \
# 1656   19970119-00:00        Thunderstorms and Rain      10.0      0       0
# 1657   19970119-01:00        Thunderstorms and Rain      11.0      0       0
# 1658   19970119-02:00        Thunderstorms and Rain      11.0      0       0
# 1659   19970119-03:00        Thunderstorms and Rain      10.0      0       0
# 1661   19970119-05:00                          Rain      10.0      0       0
# 1954   19970202-01:00                    Light Rain      11.0      0       0
# 1957   19970202-04:00                    Light Rain      13.0      0       0
# 1987   19970203-12:00                    Light Rain      15.0      0       0
# 2764   19970313-00:00                    Light Rain      13.0      0       0
# 2766   19970313-02:00                    Light Rain      15.0      0       0
# 2845   19970322-05:00                    Light Rain      15.0      0       0
# ...

# %%
booleans = []
for i in data[' _fog']:
    booleans.append( i != 0)
data_fog = data[booleans]
#print (data_fog)
print (data_fog.shape)
# Out:
# (3205, 20)

# %%
data_rain_fog = pd.merge(data_rain, data_fog, how = 'inner')
#print( data_fog )

# %%
booleans = [] 
for i in data[' _thunder']:
    booleans.append(i == 1)
data_thunder = (data[booleans])

# %%
data_rain_thunder = pd.merge(data_rain, data_thunder, how = 'inner')
#print (data_rain_thunder)
print("data_rain_thunder size:", data_rain_thunder.shape)
print("data_rain:", data_rain.shape)
print("data_thunder", data_thunder.shape)
# Out:
# ('data_rain_thunder size:', (301, 20))
# ('data_rain:', (1141, 20))
# ('data_thunder', (407, 20))

# %%
booleans = []
for i in data[' _tornado']:
    booleans.append( i == 1 )
data_tornado = data[booleans]
print (data_tornado)
# Out:
#          datetime_utc        _conds   _dewptm   _fog   _hail   _heatindexm  \
# 14805  19990819-09:30  Funnel Cloud      16.0      0       0          37.5
#
#         _hum   _precipm   _pressurem   _rain   _snow   _tempm   _thunder  \
# 14805   29.0        NaN       1005.0       0       0     37.0          0
#
#         _tornado   _vism   _wdird  _wdire   _wgustm   _windchillm   _wspdm
# 14805          1     5.0     40.0      NE       NaN           NaN      9.3

# %%
_sum = data.sum(axis =0, skipna = True)
print _sum
# Out:
# datetime_utc    19961101-11:0019961101-12:0019961101-13:001996...
#  _conds         SmokeSmokeSmokeSmokeSmokeSmokeSmokeSmokeSmokeS...
#  _dewptm                                                   778428
#  _fog                                                        3205
#  _hail                                                          1
#  _heatindexm                                               844190
#  _hum                                                 2.90915e+06
#  _precipm                                                       0
#  _pressurem                                           1.44756e+08
#  _rain                                                       1141
#  _snow                                                          0
#  _tempm                                               1.29633e+06
#  _thunder                                                     407
#  _tornado                                                       1
# ...

# %%
_avg = []
l = float(data.shape[0])
for i in _sum:
    if type(i) == int or type(i) == float:
        _avg.append(float(i)/ l)
print ( _avg)
# Out:
# [15.415942172492326, 0.06347163085454005, 1.9803940984255867e-05, 16.71828893949876, 57.61261511040697, 0.0, 2866.7354371719975, 0.022596296663035944, 0.0, 25.672482424002375, 0.008060203980592137, 1.9803940984255867e-05, 2.4843192395286513, 146.66566986830378, 0.5799663333003251, 0.04773938013664722, 8.239893058717762]

# %%
#df[' _thunder']

# %%
temp = (df['datetime_utc'], df[' _thunder'], df[' _tornado'])
#print (temp)

# %%
o = zip(df['datetime_utc'], df[' _rain'])

# %%
data.head(10)
# Out:
#      datetime_utc  _conds   _dewptm   _fog   _hail   _heatindexm   _hum  \
# 0  19961101-11:00   Smoke       9.0      0       0           NaN   27.0
# 1  19961101-12:00   Smoke      10.0      0       0           NaN   32.0
# 2  19961101-13:00   Smoke      11.0      0       0           NaN   44.0
# 3  19961101-14:00   Smoke      10.0      0       0           NaN   41.0
# 4  19961101-16:00   Smoke      11.0      0       0           NaN   47.0
# 5  19961101-17:00   Smoke      12.0      0       0           NaN   56.0
# 6  19961101-18:00   Smoke      13.0      0       0           NaN   60.0
# 7  19961101-19:00   Smoke      13.0      0       0           NaN   60.0
# 8  19961101-20:00   Smoke      13.0      0       0           NaN   68.0
# 9  19961101-21:00   Smoke      13.0      0       0           NaN   68.0
#
#     _precipm   _pressurem   _rain   _snow   _tempm   _thunder   _tornado  \
# 0        NaN       1010.0       0       0     30.0          0          0
# ...

# %%
data = df[:df.shape[0]/2]

# %%
data
# Out:
#          datetime_utc  _conds   _dewptm   _fog   _hail   _heatindexm   _hum  \
# 0      19961101-11:00   Smoke       9.0      0       0           NaN   27.0
# 1      19961101-12:00   Smoke      10.0      0       0           NaN   32.0
# 2      19961101-13:00   Smoke      11.0      0       0           NaN   44.0
# 3      19961101-14:00   Smoke      10.0      0       0           NaN   41.0
# 4      19961101-16:00   Smoke      11.0      0       0           NaN   47.0
# 5      19961101-17:00   Smoke      12.0      0       0           NaN   56.0
# 6      19961101-18:00   Smoke      13.0      0       0           NaN   60.0
# 7      19961101-19:00   Smoke      13.0      0       0           NaN   60.0
# 8      19961101-20:00   Smoke      13.0      0       0           NaN   68.0
# 9      19961101-21:00   Smoke      13.0      0       0           NaN   68.0
# 10     19961101-22:00   Smoke      13.0      0       0           NaN   68.0
# ...

# %%
data[' _hum'].fillna(0)
data[' _fog'].fillna(0)
data1 = zip(data[' _hum'], data[' _fog'])

# %%
avg_hum = data[' _hum'].sum( axis = 0, skipna =' True')/ data.shape[0]

# %%
data_fog
# Out:
#          datetime_utc       _conds   _dewptm   _fog   _hail   _heatindexm  \
# 671    19961203-20:00  Shallow Fog       8.0      1       0           NaN
# 673    19961204-00:00  Shallow Fog       8.0      1       0           NaN
# 674    19961204-01:00  Shallow Fog       8.0      1       0           NaN
# 675    19961204-02:00  Shallow Fog       8.0      1       0           NaN
# 676    19961204-03:00  Shallow Fog       8.0      1       0           NaN
# 883    19961214-00:00  Shallow Fog       4.0      1       0           NaN
# 884    19961214-01:00  Shallow Fog       4.0      1       0           NaN
# 947    19961217-00:00  Shallow Fog       5.0      1       0           NaN
# 948    19961217-01:00  Shallow Fog       5.0      1       0           NaN
# 965    19961217-20:00  Shallow Fog       6.0      1       0           NaN
# 966    19961217-21:00  Shallow Fog       5.0      1       0           NaN
# 967    19961217-22:00  Shallow Fog       5.0      1       0           NaN
# ...

# %%
booleans = []
for i in data_fog[' _hum']:
    booleans.append( i < avg_hum )
rare_fog = data_fog[(booleans)]
print (data_fog.shape, rare_fog.shape)
print (rare_fog)
# Out:
# ((3205, 20), (5, 20))
#          datetime_utc       _conds   _dewptm   _fog   _hail   _heatindexm  \
# 17235  19991211-05:30  Shallow Fog       9.0      1       0           NaN
# 17594  19991228-15:30          Fog       1.0      1       0           NaN
# 23760  20010130-23:30  Shallow Fog     -12.0      1       0           NaN
# 31005  20011212-06:30          Fog      12.0      1       0           NaN
# 40472  20030124-05:30  Shallow Fog       8.0      1       0           NaN
#
#         _hum   _precipm   _pressurem   _rain   _snow   _tempm   _thunder  \
# 17235   56.0        NaN       1020.0       0       0     18.0          0
# 17594   44.0        NaN       1020.0       0       0     13.0          0
# 23760   17.0        NaN       1010.0       0       0     13.0          0
# 31005   56.0        NaN       1019.0       0       0     21.0          0
# 40472   49.0        NaN       1012.0       0       0     19.0          0
#
# ...

# %%
X = [1, 2, 3, 4]
Y = [2, 4, 6, 8]
print(np.dot(X,2))
# Out:
# [2 4 6 8]

# %%
a = np.random.randn(1, 2)[0]
b = np.random.randn(1, 2)[0]
print(a, b)
np.dot(a, b)
# Out:
# (array([ 0.70574815, -0.82718856]), array([ 0.6831128 , -0.10585258]))
# 0.569665635817639

# %%
def seq(Y, T):
    return ((Y - T)*(Y - T))
    #return float(sum((np.array(X) - np.array(Y))**2) )/float(2 * batch_size)

# %%
def grad_des(X, T, a, batch_size, epochs):
    errors = []
    errf= 1000.0
    err = 0
    W = (np.random.randn(1,2)[0]*100)
    while( errf*100000 > 0.00001):
        W = (np.random.randn(1,2)[0]*100)
        for epoch in range(epochs):
            for i in range(len(X)/ batch_size-1):
                err = 0
                x = X[i: i+batch_size]
                for j in  range(batch_size):
                    err = 0
                    k = np.random.randint(0, batch_size)
                    xj = np.array(X[i+j])
                    yj = T[i+j]
                    tj = T[i+j]
                    W -= a * 1/batch_size*xj*(np.dot(xj, W) - yj)/2
                    #print ("yj", yj,"xj", xj," W:", W, " dot:", np.dot(xj,W)-yj)
                    #sleep(2)
                    errors.append((W, seq(np.dot(xj, W), yj)))
                    err += seq(np.dot(xj, W), yj)
                errf = err

            #sleep(1)
            #print("slope                       ",[X[0][1], X[19][1]], [np.dot(X[0], W), np.dot(X[19],W)])
            plt.plot([X[0][1], X[19][1]], [np.dot(X[0], W), np.dot(X[19],W)])
            plt.hold(True)
        print ("final:",errf)
        print W
        print "next iteration"
        print " "
        print " "
    return errors

# %%
x = np.linspace(start = 0.1, stop = 1000, num =10000)
y = np.linspace(start = 0.2, stop = 2000, num = 10000)
X = zip(list(np.ones((1, len(x))))[0], list(x))
Y = list(y)

# %%
plt.plot([i[1] for i in X[:20]], Y[:20], 'ro')
plt.hold(True)
error = grad_des(X, Y, 0.0159, 20, 100)
plt.hold(False)
sleep(10)
# Out:
# c:\python27\lib\site-packages\ipykernel_launcher.py:2: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#
# c:\python27\lib\site-packages\matplotlib\__init__.py:910: MatplotlibDeprecationWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   mplDeprecation)
# c:\python27\lib\site-packages\matplotlib\rcsetup.py:156: MatplotlibDeprecationWarning: axes.hold is deprecated, will be removed in 3.0
#   mplDeprecation)
# c:\python27\lib\site-packages\ipykernel_launcher.py:28: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
# ('final:', 9.365276253377838e-15)
# [-7.94240168e-04  2.00001533e+00]
# next iteration
# ...

# %%
ones = np.ones((1, len(x)))

# %%
for i in range(20):
    print(X[i], "                    ", Y[i])
plt.plot([i[1] for i in X[:20]], Y[:20], 'ro')
# Out:
# ((1.0, 0.1), '                    ', 0.2)
# ((1.0, 0.2), '                    ', 0.4)
# ((1.0, 0.3), '                    ', 0.6)
# ((1.0, 0.4), '                    ', 0.8)
# ((1.0, 0.5), '                    ', 1.0)
# ((1.0, 0.6), '                    ', 1.2)
# ((1.0, 0.7), '                    ', 1.4)
# ((1.0, 0.7999999999999999), '                    ', 1.5999999999999999)
# ((1.0, 0.8999999999999999), '                    ', 1.7999999999999998)
# ((1.0, 0.9999999999999999), '                    ', 1.9999999999999998)
# ((1.0, 1.0999999999999999), '                    ', 2.1999999999999997)
# ((1.0, 1.2), '                    ', 2.4)
# ((1.0, 1.3), '                    ', 2.6)
# ((1.0, 1.4), '                    ', 2.8)
# ((1.0, 1.5), '                    ', 3.0)
# ((1.0, 1.5999999999999999), '                    ', 3.1999999999999997)
# ((1.0, 1.7), '                    ', 3.4)
# ((1.0, 1.8), '                    ', 3.6)
# ((1.0, 1.9), '                    ', 3.8)
# ...

# %%
print(data.head())
# Out:
#      datetime_utc  _conds   _dewptm   _fog   _hail   _heatindexm   _hum  \
# 0  19961101-11:00   Smoke       9.0      0       0           NaN   27.0
# 1  19961101-12:00   Smoke      10.0      0       0           NaN   32.0
# 2  19961101-13:00   Smoke      11.0      0       0           NaN   44.0
# 3  19961101-14:00   Smoke      10.0      0       0           NaN   41.0
# 4  19961101-16:00   Smoke      11.0      0       0           NaN   47.0
#
#     _precipm   _pressurem   _rain   _snow   _tempm   _thunder   _tornado  \
# 0        NaN       1010.0       0       0     30.0          0          0
# 1        NaN      -9999.0       0       0     28.0          0          0
# 2        NaN      -9999.0       0       0     24.0          0          0
# 3        NaN       1010.0       0       0     24.0          0          0
# 4        NaN       1011.0       0       0     23.0          0          0
#
#     _vism   _wdird  _wdire   _wgustm   _windchillm   _wspdm
# ...

# %%
data.shape
# Out:
# (50495, 20)

# %%
t = data[:200]
print(t.head())
print (t[' _dewptm'].shape)
# Out:
#      datetime_utc  _conds   _dewptm   _fog   _hail   _heatindexm   _hum  \
# 0  19961101-11:00   Smoke       9.0      0       0           NaN   27.0
# 1  19961101-12:00   Smoke      10.0      0       0           NaN   32.0
# 2  19961101-13:00   Smoke      11.0      0       0           NaN   44.0
# 3  19961101-14:00   Smoke      10.0      0       0           NaN   41.0
# 4  19961101-16:00   Smoke      11.0      0       0           NaN   47.0
#
#     _precipm   _pressurem   _rain   _snow   _tempm   _thunder   _tornado  \
# 0        NaN       1010.0       0       0     30.0          0          0
# 1        NaN      -9999.0       0       0     28.0          0          0
# 2        NaN      -9999.0       0       0     24.0          0          0
# 3        NaN       1010.0       0       0     24.0          0          0
# 4        NaN       1011.0       0       0     23.0          0          0
#
#     _vism   _wdird  _wdire   _wgustm   _windchillm   _wspdm
# ...

# %%
t.fillna(0)[' _dewptm']
t.fillna(0)[' _tempm']
t.fillna(0)[' _hum']
dew  =  np.array(t.fillna(0)[' _dewptm'])
dew = dew / max(dew) -5

pressure  =  np.array(t.fillna(0)[' _pressurem'])

#print (pressure)

pressure  = pressure / 9999 -3

hum  =  np.array(t[' _hum'])
hum = hum / max(hum) -1
hum *= -1

temp  =  np.array(t[' _tempm'].fillna(0))
temp = temp /max(temp) + 1

heat_index  = np.array(t[' _heatindexm'].fillna(0))
heat_index  = heat_index / max(heat_index) + 3

wind_speed = np.array(t[' _wspdm'].fillna(0))
wind_speed = wind_speed/ max(wind_speed) + 5

visibility = np.array(t[' _vism'].fillna(0))
visibility = visibility / max(visibility) + 7

condition = np.array(t[' _conds'])
fog = np.array(t[' _fog'])
hail = np.array(t[' _hail'])
rain = np.array(t[' _rain'])
thunder = np.array(t[' _thunder'])
tornado = np.array(t[' _tornado'])
snow = np.array(t[' _snow'])

#print (pressure)

# %%
a = np.arange(1, 201)
print len(dew)
print len(a)
plt.plot(a, dew, 'y<', temp,' b^',hum, 'g>' , pressure, 'bo' , heat_index, 'ro', visibility,'yo ',wind_speed,'go',linewidth = 1,  markersize = 3)
plt.suptitle('weather prediction')
plt.legend(('dew', 'temperature', 'humidity_inverted', 'pressure', 'heat index','visibility','wind_speed'))
fig_size = plt.rcParams["figure.figsize"]
print(fig_size)
fig_size[0] = 24
fig_size[1] = 16
plt.rcParams["figure.figsize"] = fig_size
#print (fig_size)
# Out:
# 200
# 200
# [6.0, 4.0]

# %%
a = np.arange(0, 200, 1)
plt.plot(a, condition, 'ro', markersize = 3, linewidth = 1)

# %%
print(data.head())
a = data.columns
for i in range(len (a)):
    print i, a[i]
# Out:
#      datetime_utc  _conds   _dewptm   _fog   _hail   _heatindexm   _hum  \
# 0  19961101-11:00   Smoke       9.0      0       0           NaN   27.0
# 1  19961101-12:00   Smoke      10.0      0       0           NaN   32.0
# 2  19961101-13:00   Smoke      11.0      0       0           NaN   44.0
# 3  19961101-14:00   Smoke      10.0      0       0           NaN   41.0
# 4  19961101-16:00   Smoke      11.0      0       0           NaN   47.0
#
#     _precipm   _pressurem   _rain   _snow   _tempm   _thunder   _tornado  \
# 0        NaN       1010.0       0       0     30.0          0          0
# 1        NaN      -9999.0       0       0     28.0          0          0
# 2        NaN      -9999.0       0       0     24.0          0          0
# 3        NaN       1010.0       0       0     24.0          0          0
# 4        NaN       1011.0       0       0     23.0          0          0
#
#     _vism   _wdird  _wdire   _wgustm   _windchillm   _wspdm
# ...

# %%
data_num = data.iloc[:, [0,2,5, 6, 8, 11, 14, 15, 19]]#for selecting the rows and columns

# %%
data[' _hum'].fillna(min(data[' _hum']))
avg_hum = sum(data[' _hum'][:100])/100

# %%
rain_bool = []
for i in data[' _rain']:
    rain_bool.append(i != 0)
rainy_days = data[rain_bool]
rainy_days[' _hum'].fillna(95)
print(sum(rainy_days[50:60][' _hum'])/10)
print(rainy_days.shape)
#print(rainy_days[69:100][' _hum'])
temp = (rainy_days[69:100][' _hum']).tolist()
booleans = []
for i in rainy_days[' _hum']:
    booleans.append(i < 95)
exception_rain = rainy_days[booleans]
print(exception_rain.shape)
# Out:
# 94.9
# (1141, 20)
# (867, 20)

# %%
def seq(Y, T):
    return float((Y - T)*(Y - T))
    #return float(sum((np.array(X) - np.array(Y))**2) )/float(2 * batch_size)

# %%
#each individual vector is in column vector form
#X is the set of inputs with each element in the form of tuples
def grad_des(X, T, a, batch_size, epochs, _min):
    errors = []
    errf= 1000000.0
    err = 0
    #W = (np.random.randn(1,2)[0]*100).transpose()
    while(errf*100000 > _min):
        W = (np.random.randn(len(X[0]), 1))*10
        for epoch in range(epochs):
            for i in range(len(X)/ batch_size-1):
                err = 0
                x = X[i: i+batch_size]
                for j in  range(batch_size):
                    err = 0
                    k = np.random.randint(0, batch_size)
                    xj = np.array([X[i+j]]).transpose()
                    yj = T[i+j].transpose()
                    #tj = T[i+j].transpose()
                    W -= np.array([a/2 * np.dot(xj.transpose()[0],(np.dot(xj.transpose(), W)[0][0] - yj)) * 1/batch_size]).transpose()
                    #print ("yj", yj,"xj", np.array([xj]).transpose()," W:", W)#, " dot:", np.dot(xj,W)-yj)
                    #sleep(2)
                    #errors.append((np.dot(xj.transpose(), W)[0][0] , yj))
                    err += seq((np.dot(xj.transpose(), W)[0][0]), yj)
                errf = err

            #sleep(1)
            #print("slope                       ",[X[0][1], X[19][1]], [np.dot(X[0], W), np.dot(X[19],W)])
            plt.plot([X[0][1], X[10][1]], [np.dot(X[0], W), np.dot(X[10],W)])
            plt.hold(True)
        print ("final:",errf)
        print W
        print "next iteration"
        print " "
        print " "
    return errors

# %%
x = np.linspace(start = 0.1, stop = 1000, num =1000)
y = np.linspace(start = 0.2, stop = 2000, num = 1000)

X = np.array(zip(list(np.ones((1, len(x))))[0], list(x)))
print np.array([X[0][0]]).transpose()
#print(np.array([[1],[2]]).transpose())
#print(np.array([[1,2]]).transpose())
Y = list(y)
# Out:
# [1.]

# %%
plt.plot([i[1] for i in X[:20]], Y[:20], 'ro')
plt.hold(True)
error = grad_des(X, Y, 0.02, 40, 200, 10000)
plt.hold(False)
#sleep(10)
# Out:
# c:\python27\lib\site-packages\ipykernel_launcher.py:2: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#
# c:\python27\lib\site-packages\ipykernel_launcher.py:30: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
# ('final:', 3.221306782389381e-10)
# [[0.03009427]
#  [1.99951554]]
# next iteration
# c:\python27\lib\site-packages\ipykernel_launcher.py:4: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   after removing the cwd from sys.path.

# %%
booleans  = []
for i in data[data.columns[0]]:
    booleans.append('01:00' in i and '08' in i and '08-' not in i)
t = (data[booleans])

# %%
a = np.array(t[' _hum'].fillna(0).tolist())
print (a)
print (data.head())
#print( np.linspace(start = 0.1, stop = 1000, num =1000))
# Out:
# [100. 100. 100.  74.  94.  74.  79. 100.  94.  89.  89.  79. 100.  89.
#   74.  94. 100. 100. 100.  89.  89.  94.  94.  84.  89.  89.  84.  84.
#   89.  79.  84.  94.  89. 100.  79.  74.  79.  94.  84.  84.  89.  89.
#   94.  89.  89.  94.  89. 100.]
#      datetime_utc  _conds   _dewptm   _fog   _hail   _heatindexm   _hum  \
# 0  19961101-11:00   Smoke       9.0      0       0           NaN   27.0
# 1  19961101-12:00   Smoke      10.0      0       0           NaN   32.0
# 2  19961101-13:00   Smoke      11.0      0       0           NaN   44.0
# 3  19961101-14:00   Smoke      10.0      0       0           NaN   41.0
# 4  19961101-16:00   Smoke      11.0      0       0           NaN   47.0
#
#     _precipm   _pressurem   _rain   _snow   _tempm   _thunder   _tornado  \
# 0        NaN       1010.0       0       0     30.0          0          0
# 1        NaN      -9999.0       0       0     28.0          0          0
# ...

# %%
y = np.array(data[' _hum'].fillna(0).tolist())
x = np.linspace(start = 1, stop = len(y), num =len(y))

X = np.array(zip(list(np.ones((1, len(x))))[0], list(x)))
print np.array([X[0][0]]).transpose()
#print(np.array([[1],[2]]).transpose())
#print(np.array([[1,2]]).transpose())
Y = list(y)
# Out:
# [1.]

# %%
plt.plot([i[1] for i in X[:20]], Y[:20], 'ro')
plt.hold(True)
error = grad_des(X, Y, 0.0015, 200, 10, 100000)
#plt.hold(False)
#sleep(10)
# Out:
# c:\python27\lib\site-packages\ipykernel_launcher.py:2: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#
# c:\python27\lib\site-packages\ipykernel_launcher.py:30: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
# ('final:', 0.26920845289430256)
# [[-7.79057178]
#  [ 0.1495765 ]]
# next iteration

# %%
size = 200
t = data_num[:size]
x = np.arange(1, size)

# %%
booleans = []
print(data.fillna(-20).head())
for i in data.fillna(-20)[' _heatindexm']:
    booleans.append(i != -20.0)
heat_index_w = data[booleans][' _heatindexm']
print(heat_index_w.shape)
print(data[' _heatindexm'].shape)
#print(heat_index)
# Out:
#      datetime_utc  _conds   _dewptm   _fog   _hail   _heatindexm   _hum  \
# 0  19961101-11:00   Smoke       9.0      0       0         -20.0   27.0
# 1  19961101-12:00   Smoke      10.0      0       0         -20.0   32.0
# 2  19961101-13:00   Smoke      11.0      0       0         -20.0   44.0
# 3  19961101-14:00   Smoke      10.0      0       0         -20.0   41.0
# 4  19961101-16:00   Smoke      11.0      0       0         -20.0   47.0
#
#     _precipm   _pressurem   _rain   _snow   _tempm   _thunder   _tornado  \
# 0      -20.0       1010.0       0       0     30.0          0          0
# 1      -20.0      -9999.0       0       0     28.0          0          0
# 2      -20.0      -9999.0       0       0     24.0          0          0
# 3      -20.0       1010.0       0       0     24.0          0          0
# 4      -20.0       1011.0       0       0     23.0          0          0
#
#     _vism   _wdird  _wdire   _wgustm   _windchillm   _wspdm
# ...

# %%
booleans_heat = []
for i in (data.fillna(0)[' _heatindexm']):
    booleans_heat. append(i != 0)
heatindex_w = (data.fillna(0)[booleans_heat][' _heatindexm'])
temp_heat = data.fillna(0)[booleans_heat][' _tempm']
booleans_temp = []
for i in temp_heat:
    booleans_temp.append(i != 0)
temperature_w = data[booleans_heat][booleans_temp][' _tempm']
#print(temperature_w)
avg_temperature_heat = sum(temperature_w)/temperature_w.shape[0]
print "average temperature ", avg_temperature_heat
avg_heat = sum(heatindex_w)/(heatindex_w).shape[0]
print "average heat", avg_heat
# Out:
# average temperature  31.7610384128
# average heat 35.6348670325

# %%
#each individual vector is in column vector form
#X is the set of inputs with each element in the form of tuples
def grad_des(X, T, a, batch_size, epochs, _min):
    errors = []
    errf= 1000000.0
    err = 0
    #W = (np.random.randn(1,2)[0]*100).transpose()
    while(errf*100000 > _min):
        W = (np.random.randn(len(X[0]), 1))*10
        for epoch in range(epochs):
            for i in range(len(X)/ batch_size-1):
                err = 0
                x = X[i: i+batch_size]
                for j in  range(batch_size):
                    err = 0
                    k = np.random.randint(0, batch_size)
                    xj = np.array([X[i+j]]).transpose()
                    yj = T[i+j].transpose()
                    #tj = T[i+j].transpose()
                    W -= np.array([a/2 * np.dot(xj.transpose()[0],(np.dot(xj.transpose(), W)[0][0] - yj)) * 1/batch_size]).transpose()
                    #print ("yj", yj,"xj", np.array([xj]).transpose()," W:", W)#, " dot:", np.dot(xj,W)-yj)
                    #sleep(2)
                    #errors.append((np.dot(xj.transpose(), W)[0][0] , yj))
                    err += seq((np.dot(xj.transpose(), W)[0][0]), yj)
                errf = err
        print ("final:",errf)
        print W
        xs = (np.array([X[25][1],X[70][1]]))
        ys = np.array(np.array([np.dot(X[25].transpose(), W), np.dot(X[70].transpose(),W) ]).transpose()[0])
        xs=np.array([27, 50])
        ys=np.array([27*W[1]+W[0], 50*W[1]+W[0]])
        print (xs, ys)
        plt.plot(xs, ys, linewidth = 2)
        plt.hold(True)
        print "next iteration"
        print " "
        print " "
    return errors

# %%
x = np.array(data[booleans_heat][booleans_temp][' _tempm'].tolist())
y = np.array(data[booleans_heat][booleans_temp][' _heatindexm'].tolist())
X = np.array(zip(list(np.ones((1, len(x))))[0], list(x)))
Y = list(y)
plt.plot(x, y, 'ro')
plt.xlabel('temperature')
plt.ylabel('heat index')
plt.hold(True)
# Out:
# c:\python27\lib\site-packages\ipykernel_launcher.py:8: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.

# %%
x = np.array(data[booleans_heat][booleans_temp][' _tempm'].tolist())
y = np.array(data[booleans_heat][booleans_temp][' _heatindexm'].tolist())
X = np.array(zip(list(np.ones((1, len(x))))[0], list(x)))
Y = list(y)
plt.plot(x, y, 'ro')
plt.xlabel('temperature')
plt.ylabel('heat index')
plt.hold(True)

#plt.plot([30, 40], [30, 40])

error = grad_des(X, Y, 0.02, 200, 100, 10000)

plt.hold(False)
# Out:
# c:\python27\lib\site-packages\ipykernel_launcher.py:8: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
# ('final:', 0.039485927963153006)
# [[3.21459345]
#  [0.89153232]]
# (array([27, 50]), array([[27.28596612],
#        [47.79120951]]))
# next iteration
# c:\python27\lib\site-packages\ipykernel_launcher.py:34: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
# c:\python27\lib\site-packages\ipykernel_launcher.py:14: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.

# %%
#heat index is related to temperature and humidity
#humidity is related to temperature
#pressure is fairly constant
#dewptm is related to humidity
#no identified relation between visibility and humidity/temperature
#no relation between temperature and winspeed
#data_num.head()
plt.plot([0, 1,2, 3, 4], [0, 1, 4, 9, 16])
plt.hold(True)
plt.plot([0, 1, 4, 9, 16] , [0, 1,2, 3, 4])
plt.plot()
plt.plot([0, 1, 4, 9, 16] , [0, 1,2, 3, 4], 'ro')
plt.plot()
plt.plot([0, 16] , [0, 16])
plt.plot()
#plt.plot((([1,2]), ([2,4])))
plt.legend(('y=x^2', ' y^2 = x', 'y = x'))
# Out:
# c:\python27\lib\site-packages\ipykernel_launcher.py:9: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   if __name__ == '__main__':

# %%
booleans = []
for i in data.fillna(-2)[' _wspdm']:
    booleans.append(i != -2)
data[booleans]
# Out:
#          datetime_utc  _conds   _dewptm   _fog   _hail   _heatindexm   _hum  \
# 0      19961101-11:00   Smoke       9.0      0       0           NaN   27.0
# 4      19961101-16:00   Smoke      11.0      0       0           NaN   47.0
# 6      19961101-18:00   Smoke      13.0      0       0           NaN   60.0
# 14     19961102-02:00   Smoke      10.0      0       0           NaN   52.0
# 15     19961102-03:00   Smoke      10.0      0       0           NaN   46.0
# 16     19961102-04:00   Smoke      10.0      0       0           NaN   44.0
# 17     19961102-05:00   Smoke      11.0      0       0           NaN   39.0
# 18     19961102-06:00   Clear      10.0      0       0           NaN   32.0
# 19     19961102-07:00   Clear      10.0      0       0           NaN   29.0
# 20     19961102-08:00   Clear       8.0      0       0           NaN   24.0
# 21     19961102-09:00   Clear       7.0      0       0           NaN   22.0
# ...

# %%
#wdire can be accurately calculated using wdird
booleans_rain = []
for i in data[' _rain']:
    booleans_rain.append( i  == 1)
data[booleans_rain]
booleans_hum = []
for i in data.fillna(-2)[' _hum']:
    booleans_hum.append(i != -2)
avg_hum = sum(data[booleans_hum][' _hum'])/data[booleans_hum].shape[0]
print(avg_hum)
booleans_temp = []
for i in data.fillna(-2)[' _tempm']:
    booleans_temp.append(i != -2)
avg_temp = sum(data[booleans_temp][' _tempm'])/data[booleans_temp].shape[0]
print(avg_temp)
# Out:
# 58.2085917804
# 25.9173097685

# %%
plt.plot(np.array(data.fillna(0)[' _hum'].tolist()), np.array(data.fillna(0)[' _dewptm'].tolist()), 'ro', markersize = 2)
plt.xlabel('humidity', size = 15)
plt.ylabel('dew point', size = 15)
# Out:
# Text(0,0.5,'dew point')

# %%
#each individual vector is in column vector form
#X is the set of inputs with each element in the form of tuples
def grad_des(X, T, a, batch_size, epochs, _min):
    errors = []
    errf= 1000000.0
    err = 0
    #W = (np.random.randn(1,2)[0]*100).transpose()
    while(errf*100000 > _min):
        W = (np.random.randn(len(X[0]), 1))*10
        for epoch in range(epochs):
            for i in range(len(X)/ batch_size-1):
                #print W
                err = 0
                x = X[i: i+batch_size]
                for j in  range(batch_size):
                    err = 0
                    k = np.random.randint(0, batch_size)
                    xj = np.array([X[i+j]]).transpose()
                    yj = T[i+j].transpose()
                    #tj = T[i+j].transpose()
                    W -= np.array([a/2 * np.dot(xj.transpose()[0],(np.dot(xj.transpose(), W)[0][0] - yj)) * 1/batch_size]).transpose()
                    #print ("yj", yj,"xj", np.array([xj]).transpose()," W:", W)#, " dot:", np.dot(xj,W)-yj)
                    #sleep(2)
                    #errors.append((np.dot(xj.transpose(), W)[0][0] , yj))
                    #print W, xj, yj
                    '''if err > 10000:
                        print 'aaaaaaaaaaaaaaaaaaaaaa'
                        print 'a'
                        W = np.random.randn(len(X[0]), 1)'''
                    err += seq((np.dot(xj.transpose(), W)[0][0]), yj) /( batch_size)
                errf = err
        print ("final:",errf)
        print W
        xs = (np.array([X[25][1],X[70][1]]))
        ys = np.array(np.array([np.dot(X[25].transpose(), W), np.dot(X[70].transpose(),W) ]).transpose()[0])
        xs=np.array([0, 100])
        ys=np.array([0*W[1]+W[0], 100*W[1]+W[0]])
        print (xs, ys)
        plt.plot(xs, ys, linewidth = 2)
        plt.hold(True)
        print "next iteration"
        print " "
        print " "
    return errors

# %%
x = np.array(data.fillna(45)[' _hum'].tolist())
y = np.array(data.fillna(8)[' _dewptm'].tolist())
X = np.array(zip(list(np.ones((1, len(x))))[0], list(x)))
Y = list(y)
plt.plot(x, y, 'ro', markersize = 2)
plt.xlabel('temperature')
plt.ylabel('heat index')
plt.hold(True)

#plt.plot([30, 40], [30, 40])

error = grad_des(X, Y, 0.1, 5000, 1, 10000)

plt.hold(False)
# Out:
# c:\python27\lib\site-packages\ipykernel_launcher.py:8: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
# ('final:', 0.004036517105894076)
# [[3.84833785]
#  [0.27545545]]
# (array([  0, 100]), array([[ 3.84833785],
#        [31.39388304]]))
# next iteration
# c:\python27\lib\site-packages\ipykernel_launcher.py:40: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
# c:\python27\lib\site-packages\ipykernel_launcher.py:14: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.

# %%
#each individual vector is in column vector form
#X is the set of inputs with each element in the form of tuples
def grad_des(X, T, a, batch_size, epochs, _min):
    errors = []
    errf= 1000000.0
    err = 0
    #W = (np.random.randn(1,2)[0]*100).transpose()
    while(errf*100000 > _min):
        W = (np.random.randn(len(X[0]), 1))*(-10)
        #W = np.array([[50, -2]])
        for epoch in range(epochs):
            for i in range(len(X)/ batch_size-1):
            #for i in range(100):
                err = 0
                x = X[i: i+batch_size]
                for j in  range(batch_size):
                    err = 0
                    k = np.random.randint(0, batch_size)
                    xj = np.array([X[i+j]]).transpose()
                    yj = T[i+j].transpose()
                    #tj = T[i+j].transpose()
                    W -= np.array([a/2 * np.dot(xj.transpose()[0],(np.dot(xj.transpose(), W)[0][0] - yj)) * 1/batch_size]).transpose()
                    #print ("yj", yj,"xj", np.array([xj]).transpose()," W:", W)#, " dot:", np.dot(xj,W)-yj)
                    #sleep(2)
                    #errors.append((np.dot(xj.transpose(), W)[0][0] , yj))
                    err += seq((np.dot(xj.transpose(), W)[0][0]), yj)
                errf = err
        print ("final:",errf)
        print W
        xs = (np.array([X[25][1],X[70][1]]))
        ys = np.array(np.array([np.dot(X[25].transpose(), W), np.dot(X[70].transpose(),W) ]).transpose()[0])
        xs=np.array([10, 100])
        ys=np.array([10*W[1]+W[0], 100*W[1]+W[0]])
        print (xs, ys)
        plt.plot(xs, ys, linewidth = 2)
        plt.hold(True)
        print "next iteration"
        print " "
        print " "
    return errors

# %%
plt.plot(np.array(data.fillna(0)[' _hum'].tolist()), np.array(data.fillna(0)[' _tempm'].tolist()), 'ro', markersize = 2)
plt.xlabel('humidity', size = 15)
plt.ylabel('temperature', size =15)
# Out:
# Text(0,0.5,'temperature')

# %%
x = np.array(data.fillna(40)[' _hum'].tolist())
y = np.array(data.fillna(30)[' _tempm'].tolist())
X = np.array(zip(list(np.ones((1, len(x))))[0], list(x)))
Y = list(y)
plt.plot(x, y, 'ro', markersize = 2)
plt.xlabel('humidity')
plt.ylabel('temperature')
plt.hold(True)

#plt.plot([30, 40], [30, 40])

error = grad_des(X, Y, 0.1, 1000, 100, 10000)#grad_des(X, T, a, batch_size, epochs, _min)

plt.hold(False)
# Out:
# c:\python27\lib\site-packages\ipykernel_launcher.py:8: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
# ('final:', 0.0039491530565120055)
# [[31.08041747]
#  [-0.20614081]]
# (array([ 10, 100]), array([[29.01900935],
#        [10.46633632]]))
# next iteration
# c:\python27\lib\site-packages\ipykernel_launcher.py:36: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
# c:\python27\lib\site-packages\ipykernel_launcher.py:14: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.

# %%
length = 200
size0 = np.random.randint(0,1000)
size = length + size0
plt.plot(np.arange(size - size0),np.array((data.fillna(0)[size0:size][' _hum']/max(data[size0:size][' _hum'])+1).tolist()),'b', np.array((data.fillna(0)[size0:size][' _tempm']/max(data[size0:size][' _tempm']) - 1).tolist()), 'r', markersize = 5)
plt.legend(('humidity', 'temperature', 's'))
plt.hold(True)
plt.plot(np.arange(size - size0),np.array((data_time[1].fillna(30)[size0:size][' _hum']/max(data_time[1][size0:size][' _hum'])+3).tolist()),'r', np.array((data_time[1].fillna(30)[size0:size][' _tempm']/max(data_time[1][size0:size][' _tempm']) - 3).tolist()), 'b', markersize = 5)
plt.legend(('humidity', 'temperature'))

plt.plot(np.array([0,length]),np.array([3.5,3.5]), 'r--')
plt.plot(np.array([0,length]), np.array([1.5,1.5]), 'r--')
plt.plot(np.array([0,length]), np.array([-0.5,-0.5]), 'r--')
plt.plot(np.array([0,length]),np.array([-2.5,-2.5]), 'r--')
# Out:
# c:\python27\lib\site-packages\ipykernel_launcher.py:6: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.

# %%
from scipy.interpolate import make_interp_spline, BSpline

T = np.arange(size - size0)

power = np.array((data.fillna(0)[size0:size][' _hum']/max(data[size0:size][' _hum'])+1).tolist())

xnew = np.linspace(T.min(),T.max(),60) #300 represents number of points to make between T.min and T.max

spl = make_interp_spline(T, power, k=3) #BSpline object
power_smooth = spl(xnew)

print(power_smooth)

plt.plot(xnew,power_smooth, 'b', linewidth = 2)
#plt.hold(True)
plt.show()
plt.plot(T, power, 'r', linewidth = 2)
plt.show()
# Out:
# [1.42857143 1.63431516 1.73055182 1.84255102 2.03425993 1.90227429
#  1.47066323 1.33602545 1.57040419 1.79416641 1.43813181 1.33281024
#  1.32200323 1.44901504 1.72675431 1.92570815 2.00199205 1.79926932
#  1.4418039  1.29685533 1.53642433 1.67994103 1.77298846 1.89676644
#  1.65035989 1.37628899 1.32072079 1.59966323 1.68276566 1.77044796
#  1.75553053 1.64528355 1.36823083 1.39397603 1.65413158 1.7137415
#  1.80923621 1.82223088 1.52019783 1.30130172 1.30355457 1.72295466
#  1.68200706 1.81675188 1.58394486 1.28684686 1.22224589 1.46687037
#  1.52717932 1.50069035 1.82596643 1.4019224  1.25373493 1.25460554
#  1.47025243 1.59227106 1.6853011  1.91468989 1.42645091 1.50649351]

# %%
data_time = []
for a in range(10):
    data_time_bool = []
    for i in data[data.columns[0]]:
        data_time_bool.append('0'+ str(a) + ':' in i)
    data_time.append(data[data_time_bool])
for a in range(10, 24):
    data_time_bool = []
    for i in data[data.columns[0]]:
        data_time_bool.append(str(a) + ':' in i)
    data_time.append(data[data_time_bool])

# %%
data_time[10]
# Out:
#          datetime_utc  _conds   _dewptm   _fog   _hail   _heatindexm   _hum  \
# 22     19961102-10:00   Clear       7.0      0       0           NaN   22.0
# 46     19961103-10:00   Smoke      11.0      0       0           NaN   33.0
# 69     19961104-10:00   Smoke       7.0      0       0           NaN   25.0
# 86     19961106-10:00   Smoke       5.0      0       0           NaN   22.0
# 109    19961107-10:00   Smoke       7.0      0       0           NaN   23.0
# 133    19961108-10:00    Haze       6.0      0       0           NaN   25.0
# 179    19961110-10:00   Clear       4.0      0       0           NaN   20.0
# 201    19961111-10:00   Clear       2.0      0       0           NaN   18.0
# 224    19961112-10:00   Clear       5.0      0       0           NaN   20.0
# 248    19961113-10:00   Smoke      11.0      0       0           NaN   35.0
# 269    19961114-10:00   Smoke       6.0      0       0           NaN   25.0
# ...

# %%
size = 400
plt.plot(np.arange(0,size), data_time[0][:size][' _tempm'],data_time[0][:size][' _tempm'],'ro',data_time[12][:size][' _tempm'],'bo',data_time[15][:size][' _tempm'],'yo', linewidth = 0)
plt.legend(('junk', '12:00AM','12:00PM', '3:00PM'))
plt.ylabel('Temperature', size = 15)
# Out:
# Text(0,0.5,'Temperature')

# %%
bool_temp = []
for i in range(1000):
    bool_temp.append(data[i:i+1][' _dewptm'] > data[i:i+1][' _tempm'])
print([bool_temp])
# Out:
# [[0    False
# dtype: bool, 1    False
# dtype: bool, 2    False
# dtype: bool, 3    False
# dtype: bool, 4    False
# dtype: bool, 5    False
# dtype: bool, 6    False
# dtype: bool, 7    False
# dtype: bool, 8    False
# dtype: bool, 9    False
# dtype: bool, 10    False
# dtype: bool, 11    False
# dtype: bool, 12    False
# dtype: bool, 13    False
# dtype: bool, 14    False
# dtype: bool, 15    False
# dtype: bool, 16    False
# dtype: bool, 17    False
# dtype: bool, 18    False
# dtype: bool, 19    False
# dtype: bool, 20    False
# dtype: bool, 21    False
# dtype: bool, 22    False
# dtype: bool, 23    False
# dtype: bool, 24    False
# dtype: bool, 25    False
# dtype: bool, 26    False
# dtype: bool, 27    False
# dtype: bool, 28    False
# dtype: bool, 29    False
# dtype: bool, 30    False
# dtype: bool, 31    False
# dtype: bool, 32    False
# dtype: bool, 33    False
# dtype: bool, 34    False
# dtype: bool, 35    False
# dtype: bool, 36    False
# ...

# %%
booleans_temp = []
t = 5
for i in data_time[t][data_time[t].columns[0]]:
    booleans_temp .append('08' in i and '08-' not in i and '2000' not in i and '08:' not in i )
data_aug = data_time[t][booleans_temp]
size = 150
plt.plot(np.arange(size), (np.array(data_aug.fillna(30)[:size][' _tempm']/ max(data_aug[' _tempm']) - 1).tolist()), (np.array(data_aug.fillna(30)[:size][' _hum'])/ max(data_aug[' _hum']) + 1).tolist())
plt.legend(('temperature', 'humidity'))
#plt.show()
booleans_temp = []
t = 10
for i in data_time[t][data_time[t].columns[0]]:
    booleans_temp .append('08' in i and '08-' not in i and '2000' not in i and '08:' not in i )
data_aug = data_time[t][booleans_temp]
size = 150
plt.plot(np.arange(size), (np.array(data_aug.fillna(30)[:size][' _tempm']/ max(data_aug[' _tempm']) - 3).tolist()), (np.array(data_aug.fillna(30)[:size][' _hum'])/ max(data_aug[' _hum']) + 3).tolist())
plt.legend(('temperature1', 'humidity2', 'temperature1', ' humidity2'))

# %%
size = 200
dif1 =[0]+ [(np.array(data.fillna(30)[' _tempm'][i+1:i+2]) - np.array(data.fillna(30)[' _tempm'][i:i+1]))[0]  for i in range(size - 1)]
print "1 completed"
dif2 =[0]+ [dif1[i+1] - dif1[i]  for i in range(size - 1)]
print "2 completed"
dif3 =[0]+ [dif2[i+1] - dif2[i]  for i in range(size - 1)]
print "3 completed"
dif4 =[0]+ [dif3[i+1] - dif3[i]  for i in range(size - 1)]
print "4 completed"
dif5 =[0]+ [dif4[i+1] - dif4[i]  for i in range(size - 1)]
print "5 completed"
dif6 =[0]+ [dif5[i+1] - dif5[i]  for i in range(size - 1)]
print "6 completed"
# Out:
# 1 completed
# 2 completed
# 3 completed
# 4 completed
# 5 completed
# 6 completed

# %%
#dif6 =[0]+ [dif6[i+1] - dif6[i]  for i in range(size - 1)]
#print "6 completed"
plt.plot(np.arange(size), np.array(data.fillna(30)[' _tempm'][:size]))
plt.plot(np.arange(size), dif1)
plt.legend(('temperature', 'differntial', 'double differential'))
plt.plot(np.array([1, size]), np.array([0, 0]))
plt.show()

# %%
def sigmoid(z):
    return 1/(1 + exp(-z))

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
x_train = np.array(data.fillna(30)[' _hum'].tolist())
y_train = np.array(data.fillna(0)[' _rain'].tolist())

# %%
logisticRegr  =  LogisticRegression()

# %%
logisticRegr.fit(x_train.reshape(1, -1), y_train)
# Out:
# c:\python27\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-94-15a642603ec0> in <module>()
# ----> 1 logisticRegr.fit(x_train.reshape(1, -1), y_train)
#
# c:\python27\lib\site-packages\sklearn\linear_model\logistic.pyc in fit(self, X, y, sample_weight)
#    1286
#    1287         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype, order="C",
# -> 1288                          accept_large_sparse=solver != 'liblinear')
#    1289         check_classification_targets(y)
#    1290         self.classes_ = np.unique(y)
#
# ...
